# %% [markdown]
# # Santiago Valencia García - A00395902

# %%
import pandas as pd

df = pd.read_excel('transacciones.xls')

identificadores = df['Identificador']
# print(df.head())

# %%
# !pip install pyformlang
from pyformlang.finite_automaton import DeterministicFiniteAutomaton, State
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.8/126.8 kB 9.7 MB/s eta 0:00:00
# ...

# %% [markdown]
# # Primer autómata:

# %%
dfa_impuestos = DeterministicFiniteAutomaton()

dfa_impuestos.add_transitions([
    ('q0', 'i', 'q1'), ('q0', 'I', 'q1'),   # im
    ('q1', 'm', 'q2'), ('q1', 'M', 'q2'),
    ('q0', 't', 'q1b'), ('q0', 'T', 'q1b'), # tx
    ('q1b', 'x', 'q2b'), ('q1b', 'X', 'q2b'),
    ('q2', '0', 'q3'), ('q2b', '0', 'q3'),  # 000
    ('q3', '0', 'q4'),
    ('q4', '0', 'q5'),
    ('q5', '1', 'q6'), ('q5', '2', 'q6'), ('q5', '3', 'q6'),  # Dígito no cero
    ('q5', '4', 'q6'), ('q5', '5', 'q6'), ('q5', '6', 'q6'),
    ('q5', '7', 'q6'), ('q5', '8', 'q6'), ('q5', '9', 'q6'),
    ('q6', '0', 'q7'), ('q6', '1', 'q7'), ('q6', '2', 'q7'),  # Cinco dígitos adicionales
    ('q6', '3', 'q7'), ('q6', '4', 'q7'), ('q6', '5', 'q7'),
    ('q6', '6', 'q7'), ('q6', '7', 'q7'), ('q6', '8', 'q7'),
    ('q6', '9', 'q7'), ('q7', '0', 'q8'), ('q7', '1', 'q8'),
    ('q7', '2', 'q8'), ('q7', '3', 'q8'), ('q7', '4', 'q8'),
    ('q7', '5', 'q8'), ('q7', '6', 'q8'), ('q7', '7', 'q8'),
    ('q7', '8', 'q8'), ('q7', '9', 'q8'), ('q8', '0', 'q9'),
    ('q8', '1', 'q9'), ('q8', '2', 'q9'), ('q8', '3', 'q9'),
    ('q8', '4', 'q9'), ('q8', '5', 'q9'), ('q8', '6', 'q9'),
    ('q8', '7', 'q9'), ('q8', '8', 'q9'), ('q8', '9', 'q9'),
    ('q9', '0', 'q10'), ('q9', '1', 'q10'), ('q9', '2', 'q10'),
    ('q9', '3', 'q10'), ('q9', '4', 'q10'), ('q9', '5', 'q10'),
    ('q9', '6', 'q10'), ('q9', '7', 'q10'), ('q9', '8', 'q10'),
    ('q9', '9', 'q10'), ('q10', '0', 'q11'), ('q10', '1', 'q11'),
    ('q10', '2', 'q11'), ('q10', '3', 'q11'), ('q10', '4', 'q11'),
    ('q10', '5', 'q11'), ('q10', '6', 'q11'), ('q10', '7', 'q11'),
    ('q10', '8', 'q11'), ('q10', '9', 'q11'), ('q11', 'z', 'qf'),
    ('q11', 'Z', 'qf')    # Termina en 'z' o 'Z'
])

dfa_impuestos.add_start_state('q0')
dfa_impuestos.add_final_state('qf')
# Out:
# 1

# %% [markdown]
# <a href="https://ibb.co/HPFnnVj"><img src="https://i.ibb.co/1Xv88Lk/automata2.jpg" alt="automata2" border="0"></a>

# %%
print("It should be true:", dfa_impuestos.accepts('im000301234z'))
print("It should be true:", dfa_impuestos.accepts('tx000301234Z'))
print("It should be true:", dfa_impuestos.accepts('tX000301234Z'))
print("It should be false:", dfa_impuestos.accepts('sa000301234p'))
# Out:
# It should be true: True
# It should be true: True
# It should be true: True
# It should be false: False

# %% [markdown]
# ## Dataframe filtrado del primer autómata:

# %%
filter_by_taxes = df[df.apply(lambda x: dfa_impuestos.accepts(str(x['Identificador'].split()[0])), axis=1)]
filter_by_taxes
# Out:
#     Consecutivo Identificador      Fecha     Valor        Banco        Medio
# 0             1  Im000841225Z 2022-09-12    113000    OCCIDENTE  ELECTRONICO
# 1             2  TX000312491z 2022-04-17   2450000  BANCOLOMBIA  ELECTRONICO
# 5             6  iM000182181z 2021-01-22    334000         BBVA   PRESENCIAL
# 6             7  tx000333444Z 2022-10-15    180000     AVVILLAS   PRESENCIAL
# 8             9  Tx000456561z 2023-07-17   1800300  BANCOLOMBIA  ELECTRONICO
# 10           11  tx000233416z 2022-01-16     25000    OCCIDENTE   PRESENCIAL
# 12           13  iM000311110z 2022-08-10    100000   DAVIVIENDA  ELECTRONICO
# 27           28  iM000921121z 2022-10-11     34000   DAVIVIENDA  ELECTRONICO
# 42           43  tX000411223Z 2022-01-24   3800000         BBVA  ELECTRONICO
# 43           44  iM000717120Z 2022-01-17    345000  BANCOLOMBIA  ELECTRONICO
# 46           47  IM000212144z 2023-07-17   5200000   DAVIVIENDA  ELECTRONICO
# ...

# %% [markdown]
# # Segundo autómata

# %%
from pyformlang.finite_automaton import NondeterministicFiniteAutomaton

nfa_servicios = NondeterministicFiniteAutomaton()

nfa_servicios.add_transitions([
    ('q0', 's', 'q1'), ('q0', 'S', 'q1'),
    ('q1', '1', 'q2'), ('q1', '1', 'q2b'),
    ('q2', '1', 'q3'), ('q2b', '0', 'q3'),
    ('q3', '2', 'q4'), ('q3', '3', 'q4b'),
    ('q4', '2', 'q5'), ('q4b', '3', 'q5b'),
    ('q5', '0', 'q6'), ('q5', '1', 'q6'),  # Seis dígitos
    ('q5', '2', 'q6'), ('q5', '3', 'q6'),
    ('q5', '4', 'q6'), ('q5', '5', 'q6'),
    ('q5', '6', 'q6'), ('q5', '7', 'q6'),
    ('q5', '8', 'q6'), ('q5', '9', 'q6'),
    ('q5b', '0', 'q6'), ('q5b', '1', 'q6'),
    ('q5b', '2', 'q6'), ('q5b', '3', 'q6'),
    ('q5b', '4', 'q6'), ('q5b', '5', 'q6'),
    ('q5b', '6', 'q6'), ('q5b', '7', 'q6'),
    ('q5b', '8', 'q6'), ('q5b', '9', 'q6'),
    ('q6', '0', 'q7'), ('q6', '1', 'q7'),
    ('q6', '2', 'q7'), ('q6', '3', 'q7'),
    ('q6', '4', 'q7'), ('q6', '5', 'q7'),
    ('q6', '6', 'q7'), ('q6', '7', 'q7'),
    ('q6', '8', 'q7'), ('q6', '9', 'q7'),
    ('q7', '0', 'q8'), ('q7', '1', 'q8'),
    ('q7', '2', 'q8'), ('q7', '3', 'q8'),
    ('q7', '4', 'q8'), ('q7', '5', 'q8'),
    ('q7', '6', 'q8'), ('q7', '7', 'q8'),
    ('q7', '8', 'q8'), ('q7', '9', 'q8'),
    ('q8', '0', 'q9'), ('q8', '1', 'q9'),
    ('q8', '2', 'q9'), ('q8', '3', 'q9'),
    ('q8', '4', 'q9'), ('q8', '5', 'q9'),
    ('q8', '6', 'q9'), ('q8', '7', 'q9'),
    ('q8', '8', 'q9'), ('q8', '9', 'q9'),
    ('q9', '0', 'q10'), ('q9', '1', 'q10'),
    ('q9', '2', 'q10'), ('q9', '3', 'q10'),
    ('q9', '4', 'q10'), ('q9', '5', 'q10'),
    ('q9', '6', 'q10'), ('q9', '7', 'q10'),
    ('q9', '8', 'q10'), ('q9', '9', 'q10'),
    ('q10', '0', 'q11'), ('q10', '1', 'q11'),
    ('q10', '2', 'q11'), ('q10', '3', 'q11'),
    ('q10', '4', 'q11'), ('q10', '5', 'q11'),
    ('q10', '6', 'q11'), ('q10', '7', 'q11'),
    ('q10', '8', 'q11'), ('q10', '9', 'q11'),
    ('q11', 's', 'qf'), ('q11', 'S', 'qf')
])

nfa_servicios.add_start_state('q0')
nfa_servicios.add_final_state('qf')
# Out:
# 1

# %% [markdown]
# <a href="https://ibb.co/0YPJ5bF"><img src="https://i.ibb.co/F8G7pT0/automata2.jpg" alt="automata2" border="0"></a>

# %%
print("It should be true:", nfa_servicios.accepts('s1133123456s'))
print("It should be true:", nfa_servicios.accepts('S1022012345S'))
print("It should be false:", nfa_servicios.accepts('12122203h'))
# Out:
# It should be true: True
# It should be true: True
# It should be false: False

# %% [markdown]
# ## Dataframe filtrado del segundo autómata:

# %%
filter_by_services = df[df.apply(lambda x: nfa_servicios.accepts(str(x['Identificador'].split()[0])), axis=1)]
filter_by_services
# Out:
#     Consecutivo Identificador      Fecha    Valor        Banco        Medio
# 3             4  S1022121345s 2022-10-24   312000      AGRARIO  ELECTRONICO
# 14           15  s1022509981s 2021-01-01   134000  BANCOLOMBIA  ELECTRONICO
# 16           17  s1033977669S 2023-05-04    66000   DAVIVIENDA   PRESENCIAL
# 29           30  S1122199224s 2022-01-19    58000   DAVIVIENDA   PRESENCIAL
# 44           45  s1022988163s 2021-01-01   100000         BBVA   PRESENCIAL
# 56           57  s1122043042S 2022-01-18   110000    OCCIDENTE  ELECTRONICO
# 57           58  s1133432266S 2022-11-09   234000         ITAU   PRESENCIAL
# 69           70  S1122115116S 2021-01-01   520000      AGRARIO  ELECTRONICO
# 70           71  S1033080727s 2022-01-18   302000   DAVIVIENDA  ELECTRONICO
# 71           72  s1122000000S 2023-07-17    72000    OCCIDENTE   PRESENCIAL
# 78           79  S1133221670s 2021-01-01   651000  BANCOLOMBIA  ELECTRONICO
# ...

# %% [markdown]
# # Tercer autómata

# %%
from pyformlang.finite_automaton import EpsilonNFA
enfa_compras = EpsilonNFA()

enfa_compras.add_transitions([
    ('q0', 'c', 'q1'), ('q0', 'C', 'q1'), ('q0', 's', 'q1b'), ('q0', 'S', 'q1b'),
    ('q1b', 'h', 'q2'), ('q1b', 'H', 'q2'), ('q2', 'p', 'q3'), ('q2', 'P', 'q3'),
    ('q1', '-', 'q4'), ('q1', '/', 'q4'), ('q1', ':', 'q4'), ('q3', '-', 'q4'),
    ('q3', '/', 'q4'), ('q3', ':', 'q4'), ('q4', 'epsilon', 'q4a'), ('q4', 'epsilon', 'q4b'),
    ('q4a', '0', 'q5'), ('q4b', '0', 'q5'), ('q5', '0', 'q6'), ('q6', '1', 'q7'),
    ('q6', '2', 'q7'), ('q6', '3', 'q7'), ('q6', '4', 'q7'), ('q6', '5', 'q7'),
    ('q6', '6', 'q7'), ('q6', '7', 'q7'), ('q6', '8', 'q7'), ('q6', '9', 'q7'),
    ('q7', '0', 'q8'), ('q7', '1', 'q8'), ('q7', '2', 'q8'), ('q7', '3', 'q8'),
    ('q7', '4', 'q8'), ('q7', '5', 'q8'), ('q7', '6', 'q8'), ('q7', '7', 'q8'),
    ('q7', '8', 'q8'), ('q7', '9', 'q8'), ('q8', '0', 'q9'), ('q8', '1', 'q9'),
    ('q8', '2', 'q9'), ('q8', '3', 'q9'), ('q8', '4', 'q9'), ('q8', '5', 'q9'),
    ('q8', '6', 'q9'), ('q8', '7', 'q9'), ('q8', '8', 'q9'), ('q8', '9', 'q9'),
    ('q9', '0', 'q10'), ('q9', '1', 'q10'), ('q9', '2', 'q10'), ('q9', '3', 'q10'),
    ('q9', '4', 'q10'), ('q9', '5', 'q10'), ('q9', '6', 'q10'), ('q9', '7', 'q10'),
    ('q9', '8', 'q10'), ('q9', '9', 'q10'), ('q10', '0', 'q11'), ('q10', '1', 'q11'),
    ('q10', '2', 'q11'), ('q10', '3', 'q11'), ('q10', '4', 'q11'), ('q10', '5', 'q11'),
    ('q10', '6', 'q11'), ('q10', '7', 'q11'), ('q10', '8', 'q11'), ('q10', '9', 'q11'),
    ('q11', '0', 'q12'), ('q11', '1', 'q12'), ('q11', '2', 'q12'), ('q11', '3', 'q12'),
    ('q11', '4', 'q12'), ('q11', '5', 'q12'), ('q11', '6', 'q12'), ('q11', '7', 'q12'),
    ('q11', '8', 'q12'), ('q11', '9', 'q12'), ('q12', '0', 'q13'), ('q12', '1', 'q13'),
    ('q12', '2', 'q13'), ('q12', '3', 'q13'), ('q12', '4', 'q13'), ('q12', '5', 'q13'),
    ('q12', '6', 'q13'), ('q12', '7', 'q13'), ('q12', '8', 'q13'), ('q12', '9', 'q13'),
    ('q13', '0', 'q14'), ('q13', '1', 'q14'), ('q13', '2', 'q14'), ('q13', '3', 'q14'),
    ('q13', '4', 'q14'), ('q13', '5', 'q14'), ('q13', '6', 'q14'), ('q13', '7', 'q14'),
    ('q13', '8', 'q14'), ('q13', '9', 'q14'), ('q14', '0', 'q15'), ('q14', '1', 'q15'),
    ('q14', '2', 'q15'), ('q14', '3', 'q15'), ('q14', '4', 'q15'), ('q14', '5', 'q15'),
    ('q14', '6', 'q15'), ('q14', '7', 'q15'), ('q14', '8', 'q15'), ('q14', '9', 'q15'),
    ('q15', 'Y', 'qf')
                              ])

enfa_compras.add_start_state('q0')
enfa_compras.add_final_state('qf')
# Out:
# 1

# %% [markdown]
# <a href="https://ibb.co/hgqq1z7"><img src="https://i.ibb.co/TwCCq3v/automata3.jpg" alt="automata3" border="0"></a>

# %%
print("It should be true:", enfa_compras.accepts('sHp/00412345678Y'))
print("It should be true:", enfa_compras.accepts('sHP:00412345678Y'))
print("It should be true:", enfa_compras.accepts('SHp:00412345678Y'))
print("It should be true:", enfa_compras.accepts('ShP-00412345678Y'))
print("It should be true:", enfa_compras.accepts('c:00412345678Y'))
print("It should be true:", enfa_compras.accepts('C-004123457678Y'))
print("It should be false:", enfa_compras.accepts('H_:00412345678Y'))
# Out:
# It should be true: True
# It should be true: True
# It should be true: True
# It should be true: True
# It should be true: True
# It should be true: False
# It should be false: False

# %% [markdown]
# ## Dataframe filtrado del tercer autómata

# %%
filter_by_purchases = df[df.apply(lambda x: enfa_compras.accepts(str(x['Identificador'].split()[0])), axis=1)]
filter_by_purchases
# Out:
#     Consecutivo     Identificador      Fecha     Valor        Banco  \
# 2             3  shP/00234345560Y 2022-12-12  10800000   DAVIVIENDA
# 7             8    c-00710105051Y 2022-11-11     22000      POPULAR
# 20           21  shp:00122334196Y 2021-06-05   2300000      AGRARIO
# 21           22    C/00510201020Y 2023-07-17    112000      AGRARIO
# 23           24  SHP-00901020605Y 2023-07-01    465000   DAVIVIENDA
# 26           27  ShP/00967562889Y 2022-09-12   1700000  BANCOLOMBIA
# 32           33    c-00911342110Y 2022-04-18    345000  BANCOLOMBIA
# 33           34    c-00890878790Y 2023-03-30    138000      POPULAR
# 34           35    C:00466578091Y 2022-11-12     98000    OCCIDENTE
# 35           36  shp/00454565755Y 2022-04-18    557000     AVVILLAS
# 36           37    c:00978651023Y 2021-06-03   3800000  BANCOLOMBIA
# 37           38    c-00988664432Y 2023-01-01     23000   BANCOOMEVA
# 38           39    C-00222002112Y 2022-04-17    122000         BBVA
# ...
